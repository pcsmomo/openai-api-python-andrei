# %%
import openai
import os

# %%
openai.api_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Making an API call to DALL-E

# %%
image_prompt= 'Man on a motocycle on a cyberpunk street, high quality photography.'

response = openai.Image.create(
    prompt=image_prompt,
    n=1,
    size='1024x1024'
)

print(response)
# Out:
# {
#   "created": 1682398910,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-gLCtXyaA7aD0Tjof0bYJ8GkI/user-c9gctj0DJT5qKXMbdyZDrN2d/img-jVmm5kTza8WBUiXh3UPqec6G.png?st=2023-04-25T04%3A01%3A50Z&se=2023-04-25T06%3A01%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-25T04%3A20%3A04Z&ske=2023-04-26T04%3A20%3A04Z&sks=b&skv=2021-08-06&sig=P%2BNzKKkf8bKx6qKcCM1oFi2LgoZ46IdEOsSih5p6QJ0%3D"
#     }
#   ]
# }

# %%
image_url = response['data'][0]['url']
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-gLCtXyaA7aD0Tjof0bYJ8GkI/user-c9gctj0DJT5qKXMbdyZDrN2d/img-jVmm5kTza8WBUiXh3UPqec6G.png?st=2023-04-25T04%3A01%3A50Z&se=2023-04-25T06%3A01%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-25T04%3A20%3A04Z&ske=2023-04-26T04%3A20%3A04Z&sks=b&skv=2021-08-06&sig=P%2BNzKKkf8bKx6qKcCM1oFi2LgoZ46IdEOsSih5p6QJ0%3D

# %% [markdown]
# ### Save image to a file on disk

# %%
# Installing the required libraries

# !pip install -q requests
# !pip install Pillow

# %%
import requests
import shutil


resource = requests.get(image_url, stream=True)

print(resource.status_code)

if resource.status_code == 200:
    with open('dalle1.png', 'wb') as f:
        # resource.raw.decode_content = True
        shutil.copyfileobj(resource.raw, f)   
else:
    print('Error accessing the image!')
# Out:
# 200

# %%
from PIL import Image

# reduced the size of the image, https://resizing.app/features/resize-png/

Image.open('17-dalle1x256.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=256x256>
