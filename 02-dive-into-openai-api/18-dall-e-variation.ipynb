# %%
import openai
import os

# %%
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
image = open('18-original.png', 'rb')

response = openai.Image.create_variation(
    image=image,
    n=1,
    size='1024x1024'
)

# %%
print(response)
image_url = response['data'][0]['url']
print(image_url)
# Out:
# {
#   "created": 1682404795,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-gLCtXyaA7aD0Tjof0bYJ8GkI/user-c9gctj0DJT5qKXMbdyZDrN2d/img-Juj4qW52CLe7PO50yUJ83nLm.png?st=2023-04-25T05%3A39%3A55Z&se=2023-04-25T07%3A39%3A55Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-25T06%3A37%3A42Z&ske=2023-04-26T06%3A37%3A42Z&sks=b&skv=2021-08-06&sig=0ljTHHop5zp1GlmKKWocfMiZ6vc8Vmg/KpsR/VoVXHA%3D"
#     }
#   ]
# }
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-gLCtXyaA7aD0Tjof0bYJ8GkI/user-c9gctj0DJT5qKXMbdyZDrN2d/img-Juj4qW52CLe7PO50yUJ83nLm.png?st=2023-04-25T05%3A39%3A55Z&se=2023-04-25T07%3A39%3A55Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-04-25T06%3A37%3A42Z&ske=2023-04-26T06%3A37%3A42Z&sks=b&skv=2021-08-06&sig=0ljTHHop5zp1GlmKKWocfMiZ6vc8Vmg/KpsR/VoVXHA%3D

# %%
import requests
import shutil


resource = requests.get(image_url, stream=True)

print(resource.status_code)

if resource.status_code == 200:
    with open('18-variation.png', 'wb') as f:
        # resource.raw.decode_content = True
        shutil.copyfileobj(resource.raw, f)   
else:
    print('Error accessing the image!')
# Out:
# 200

# %%
from PIL import Image

# reduced the size of the image, https://resizing.app/features/resize-png/
Image.open('18-originalx256.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256>

# %%
Image.open('18-variationx256.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=256x256>
